# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("housing.csv")
data.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.info()
#checking there is any null values
data.dropna(inplace = True)
data.info() #after droping
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(["median_house_value"],axis = 1)
y = data["median_house_value"]
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12393    -116.42     33.68                15.0       3895.0           782.0
# 1687     -122.27     37.99                16.0       4921.0           737.0
# 15151    -117.05     33.01                19.0       3558.0           588.0
# 19552    -120.99     37.63                21.0        319.0           120.0
# 1286     -121.82     38.01                25.0       3018.0           606.0
# ...          ...       ...                 ...          ...             ...
# 18527    -122.04     36.97                49.0        792.0           136.0
# 19006    -121.98     38.32                45.0         19.0             5.0
# 3693     -118.38     34.21                42.0        715.0           145.0
# 18006    -121.97     37.30                31.0       3340.0           735.0
# 20166    -119.29     34.44                34.0       4314.0           878.0
#
#        population  households  median_income ocean_proximity  \
# 12393       900.0       529.0         2.2208          INLAND
# 1687       2312.0       725.0         5.8899        NEAR BAY
# 15151      1439.0       578.0         4.6250       <1H OCEAN
# 19552       276.0        85.0         2.4792          INLAND
# 1286       1614.0       568.0         3.4722          INLAND
# ...           ...         ...            ...             ...
# 18527       331.0       137.0         5.2128      NEAR OCEAN
# 19006      7460.0         6.0        10.2264          INLAND
# 3693        730.0       158.0         3.8000       <1H OCEAN
# 18006      1891.0       686.0         4.8542       <1H OCEAN
# 20166      2361.0       831.0         3.2279      NEAR OCEAN
#
#        median_house_value
# 12393            138300.0
# 1687             243200.0
# 15151            211100.0
# 19552             60000.0
# 1286             127000.0
# ...                   ...
# 18527            238600.0
# 19006            137500.0
# 3693             169500.0
# 18006            275000.0
# 20166            243100.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
numeric_train_data = train_data.select_dtypes(include=['float64', 'int64'])
numeric_train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924746           -0.107609     0.039821
# latitude            -0.924746  1.000000            0.011060    -0.029818
# housing_median_age  -0.107609  0.011060            1.000000    -0.365882
# total_rooms          0.039821 -0.029818           -0.365882     1.000000
# total_bedrooms       0.062675 -0.059786           -0.325468     0.930756
# population           0.097359 -0.105504           -0.306004     0.865676
# households           0.049997 -0.064590           -0.306540     0.919791
# median_income       -0.017409 -0.077602           -0.118710     0.197307
# median_house_value  -0.050107 -0.139878            0.109056     0.132157
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.062675    0.097359    0.049997      -0.017409
# latitude                 -0.059786   -0.105504   -0.064590      -0.077602
# housing_median_age       -0.325468   -0.306004   -0.306540      -0.118710
# total_rooms               0.930756    0.865676    0.919791       0.197307
# total_bedrooms            1.000000    0.886272    0.980521      -0.007942
# population                0.886272    1.000000    0.914675       0.005556
# households                0.980521    0.914675    1.000000       0.012189
# median_income            -0.007942    0.005556    0.012189       1.000000
# median_house_value        0.050448   -0.026937    0.064923       0.685484
#
#                     median_house_value
# longitude                    -0.050107
# latitude                     -0.139878
# housing_median_age            0.109056
# total_rooms                   0.132157
# total_bedrooms                0.050448
# population                   -0.026937
# households                    0.064923
# median_income                 0.685484
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(numeric_train_data.corr(),annot = True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
numeric_train_data["total_rooms"] = np.log(numeric_train_data["total_rooms"] + 1)
numeric_train_data["total_bedrooms"] = np.log(numeric_train_data["total_bedrooms"] + 1)
numeric_train_data["population"] = np.log(numeric_train_data["population"] + 1)
numeric_train_data["households"] = np.log(numeric_train_data["households"] + 1)

numeric_train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"],axis = 1)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12393    -116.42     33.68                15.0       3895.0           782.0
# 1687     -122.27     37.99                16.0       4921.0           737.0
# 15151    -117.05     33.01                19.0       3558.0           588.0
# 19552    -120.99     37.63                21.0        319.0           120.0
# 1286     -121.82     38.01                25.0       3018.0           606.0
# ...          ...       ...                 ...          ...             ...
# 18527    -122.04     36.97                49.0        792.0           136.0
# 19006    -121.98     38.32                45.0         19.0             5.0
# 3693     -118.38     34.21                42.0        715.0           145.0
# 18006    -121.97     37.30                31.0       3340.0           735.0
# 20166    -119.29     34.44                34.0       4314.0           878.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12393       900.0       529.0         2.2208            138300.0      False
# 1687       2312.0       725.0         5.8899            243200.0      False
# 15151      1439.0       578.0         4.6250            211100.0       True
# 19552       276.0        85.0         2.4792             60000.0      False
# 1286       1614.0       568.0         3.4722            127000.0      False
# ...           ...         ...            ...                 ...        ...
# 18527       331.0       137.0         5.2128            238600.0      False
# 19006      7460.0         6.0        10.2264            137500.0      False
# 3693        730.0       158.0         3.8000            169500.0       True
# 18006      1891.0       686.0         4.8542            275000.0       True
# 20166      2361.0       831.0         3.2279            243100.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12393    True   False     False       False
# 1687    False   False      True       False
# 15151   False   False     False       False
# 19552    True   False     False       False
# 1286     True   False     False       False
# ...       ...     ...       ...         ...
# 18527   False   False     False        True
# 19006    True   False     False       False
# 3693    False   False     False       False
# 18006   False   False     False       False
# 20166   False   False     False        True
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot = True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
